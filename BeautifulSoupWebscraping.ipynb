# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\91810\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\91810\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=8a5dc1f255b577cae7d5aa7618a16031c88f337e3041fcf8820fe7e9869d75fb
#   Stored in directory: c:\users\91810\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"

# %%
soup = BeautifulSoup(html, 'html5lib')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %% [markdown]
# ### Tags

# %%
tag_object=soup.title
print("tag object:",tag_object)
# Out:
# tag object: <title>Page Title</title>

# %%
print("tag object type:",type(tag_object))
# Out:
# tag object type: <class 'bs4.element.Tag'>

# %%
tag_object=soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %% [markdown]
# ### Children, parents and siblings

# %%
tag_child =tag_object.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %%
parent_tag=tag_child.parent
parent_tag
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_object.parent
# Out:
# <body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body>

# %%
sibling_1=tag_object.next_sibling
sibling_1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %%
sibling_2=sibling_1.next_sibling
sibling_2
# Out:
# <h3> Stephen Curry</h3>

# %%
sibling_3=sibling_2.next_sibling
sibling_3
# Out:
# <p> Salary: $85,000, 000 </p>

# %% [markdown]
# ### HTML Attributes

# %%
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %%
tag_child['id']
# Out:
# 'boldest'

# %%
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %%
tag_child.get('id')
# Out:
# 'boldest'

# %% [markdown]
# ### Navigable String

# %%
tag_string=tag_child.string
tag_string
# Out:
# 'Lebron James'

# %%
type(tag_string)
# Out:
# bs4.element.NavigableString

# %%
unicode_string = str(tag_string)
unicode_string
# Out:
# 'Lebron James'

# %%
type(unicode_string)
# Out:
# str

# %% [markdown]
# ### Filter

# %%
table="<table><tr><td id='flight'>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td><td>80 kg</td></tr></table>"

# %%
table_bs = BeautifulSoup(table, 'html5lib')

# %%
# Find all rows BY ATTRIBUTEtable_bs.find_all(href=True)
table_rows=table_bs.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>300 kg</td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr>]

# %%
first_row =table_rows[0]
first_row
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>

# %%
print(type(first_row))
# Out:
# <class 'bs4.element.Tag'>

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %%
for i,row in enumerate(table_rows):
    print("row",i)
    cells=row.find_all('td')
    for j,cell in enumerate(cells):
        print('colunm',j,"cell",cell)
# Out:
# row 0
# colunm 0 cell <td id="flight">Flight No</td>
# colunm 1 cell <td>Launch site</td>
# colunm 2 cell <td>Payload mass</td>
# row 1
# colunm 0 cell <td>1</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td>
# colunm 2 cell <td>300 kg</td>
# row 2
# colunm 0 cell <td>2</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# colunm 2 cell <td>94 kg</td>
# row 3
# colunm 0 cell <td>3</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td>
# colunm 2 cell <td>80 kg</td>

# %%
list_input=table_bs .find_all(name=["tr", "td"])
list_input
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td>,
#  <td>80 kg</td>]

# %%
# finad all by name
table_bs.find_all(id="flight")
# Out:
# [<td id="flight">Flight No</td>]

# %%
list_input=table_bs.find_all(href="https://en.wikipedia.org/wiki/Florida")
list_input
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]

# %%
table_bs.find_all(href=True)
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida</a>,
#  <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida</a>]

# %%
table_bs.find_all(href=False)
# Out:
# [<html><head></head><body><table><tbody><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr></tbody></table></body></html>,
#  <head></head>,
#  <body><table><tbody><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr></tbody></table></body>,
#  <table><tbody><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr></tbody></table>,
#  <tbody><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr></tbody>,
#  <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td>,
#  <a></a>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a> </a></td>,
#  <a> </a>,
#  <td>80 kg</td>]

# %%
soup.find_all(id='boldest')
# Out:
# [<b id="boldest">Lebron James</b>]

# %%
table_bs.find_all(string="Florida")
# Out:
# ['Florida', 'Florida']

# %%
# Find method 
two_tables="<h3>Rocket Launch </h3><p><table class='rocket'><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class='pizza'><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td >144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr>"

# %%
two_tables_bs= BeautifulSoup(two_tables, 'html.parser')

# %%
two_tables_bs.find("table")
# Out:
# <table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>

# %%
two_tables_bs.find("table",class_='pizza')
# Out:
# <table class="pizza"><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table>

# %% [markdown]
# #### Exercise

# %%
url = "http://www.ibm.com"
data  = requests.get(url).text
soup = BeautifulSoup(data,"html5lib")

# %%
for link in soup.find_all('a',href=True):  # in html anchor/link is represented by the tag <a>

    print(link.get('href'))
# Out:
# https://www.ibm.com/in/en
# https://www.ibm.com/sitemap/in/en
# /in-en/consulting?lnk=hpv18l1
# https://www.ibm.com/in-en/about?lnk=hpv18nf#2825811
# /in-en/analytics/data-fabric?lnk=hpv18f1
# /in-en/cloud/cloud-pak-for-watson-aiops?lnk=hpv18f2
# https://www.ibm.com/blogs/digital-transformation/in-en/blog/happiest-minds-accelerates-investigation-time-with-ibm-security-qradar/?lnk=hpv18f3
# /in-en/cloud/paks?lnk=hpv18f4
# /in-en/cloud/free?lnk=hpv18t1&psrc=NONE&pexp=DEF&lnk2=trial_Cloud
# /in-en/cloud/watson-assistant?lnk=hpv18t2&psrc=NONE&lnk2=trial_AsperaCloud&pexp=DEF
# https://www.ibm.com/account/reg/signup?formid=urx-46597&lnk=hpv18t3&psrc=NONE&pexp=DEF&lnk2=trial_RoboticProcess
# /in-en/products/cloud-pak-for-data?lnk=hpv18t4&psrc=NONE&pexp=DEF&lnk2=trial_CloudPakData
# https://developer.ibm.com/depmodels/cloud/?lnk=hpv18pd1
# https://developer.ibm.com/technologies/artificial-intelligence?lnk=hpv18pd2
# https://www.ibm.com/demos/?lnk=hpv18pd3
# https://developer.ibm.com/?lnk=hpv18pd4
# https://www.ibm.com/docs/en?lnk=hpv18pd5
# https://www.redbooks.ibm.com/?lnk=hpv18pd6
# https://www.ibm.com/support/home/?lnk=hpv18pd7
# https://www.ibm.com/training/?lnk=hpv18pd8
# /in-en/cloud/hybrid?lnk=hpv18pb1
# /cloud/learn/public-cloud?lnk=hpv18pb2
# /in-en/watson?lnk=hpv18pb3
# /in-en/garage?lnk=hpv18pb4
# /in-en/blockchain?lnk=hpv18pb5
# https://www.ibm.com/thought-leadership/institute-business-value/?lnk=hpv18pb6
# /in-en/analytics?lnk=hpv18pb7
# /in-en/security?lnk=hpv18pb8
# /in-en/financing?lnk=hpv18pb9
# /in-en/cloud/redhat?lnk=hpv18pt1
# /in-en/cloud/automation?lnk=hpv18pt2
# /in-en/cloud/satellite?lnk=hpv18pt3
# /in-en/security/zero-trust?lnk=hpv18pt4
# /in-en/it-infrastructure?lnk=hpv18pt5
# https://www.ibm.com/quantum-computing?lnk=hpv18pt6
# /in-en/cloud/learn/kubernetes?lnk=hpv18pt7
# /in-en/products/spss-statistics?lnk=ushpv18pt8
# /in-en/blockchain?lnk=hpv18pt9
# https://www.ibm.com/in-en/employment?lnk=hpv18pt10
# https://developer.ibm.com/conferences/build-smart-on-kubernetes-India?lnk=hpv18cs1
# /case-studies/search?lnk=hpv18cs2
# #

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))
# Out:
# <img alt="data fabric" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-10-01/Original-20210830-f-data-fabric-26047.png"/>
# //1.cms.s81c.com/sites/default/files/2021-10-01/Original-20210830-f-data-fabric-26047.png
# <img alt="Watson AIOps" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-10-01/Small-ibm-AIOps-20210809-mobile.jpg"/>
# //1.cms.s81c.com/sites/default/files/2021-10-01/Small-ibm-AIOps-20210809-mobile.jpg
# <img alt="cyber security centre" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-09-29/Small-17_55_p_gorodenkoff-026.jpg"/>
# //1.cms.s81c.com/sites/default/files/2021-09-29/Small-17_55_p_gorodenkoff-026.jpg
# <img alt="cloud pak" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-09-19/Original-67e9de4f-33de-47c4-9fe58c0535f9f04a.jpg"/>
# //1.cms.s81c.com/sites/default/files/2021-09-19/Original-67e9de4f-33de-47c4-9fe58c0535f9f04a.jpg
# <img alt="screenshot of the IBM Cloud dashboard" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-04-07/ibm-cloud-trial.png"/>
# //1.cms.s81c.com/sites/default/files/2021-04-07/ibm-cloud-trial.png
# <img alt="screenshot of watson assistant" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-08-17/Watson-Assistant-23212-700x420.png"/>
# //1.cms.s81c.com/sites/default/files/2021-08-17/Watson-Assistant-23212-700x420.png
# <img alt="Screenshot of IBM RPA" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-04-09/robotic-process-automation.png"/>
# //1.cms.s81c.com/sites/default/files/2021-04-09/robotic-process-automation.png
# <img alt="Cloud pak for data screenshot" class="" loading="lazy" src="//1.cms.s81c.com/sites/default/files/2021-04-07/cloud-pak-for-data-trial.png"/>
# //1.cms.s81c.com/sites/default/files/2021-04-07/cloud-pak-for-data-trial.png

# %% [markdown]
# ### Scrape data from HTML tables

# %%
#The below url contains an html table with data about colors and color codes.
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %%
data  = requests.get(url).text
soup = BeautifulSoup(data,"html5lib")

# %%
table = soup.find('table')

# %%
for row in table.find_all('tr'):
    print(type(row))
    for cols in row.find_all('td'):
        print(type(row), type(cols))
        print(row,cols)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>Number </td>
#       <td>Color</td>
#       <td>Color Name</td>
#       <td>Hex Code<br/>#RRGGBB</td>
#       <td>Decimal Code<br/>(R,G,B)</td>
#    </tr> <td>Number </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>Number </td>
#       <td>Color</td>
#       <td>Color Name</td>
#       <td>Hex Code<br/>#RRGGBB</td>
#       <td>Decimal Code<br/>(R,G,B)</td>
#    </tr> <td>Color</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>Number </td>
#       <td>Color</td>
#       <td>Color Name</td>
#       <td>Hex Code<br/>#RRGGBB</td>
#       <td>Decimal Code<br/>(R,G,B)</td>
#    </tr> <td>Color Name</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>Number </td>
#       <td>Color</td>
#       <td>Color Name</td>
#       <td>Hex Code<br/>#RRGGBB</td>
#       <td>Decimal Code<br/>(R,G,B)</td>
#    </tr> <td>Hex Code<br/>#RRGGBB</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>Number </td>
#       <td>Color</td>
#       <td>Color Name</td>
#       <td>Hex Code<br/>#RRGGBB</td>
#       <td>Decimal Code<br/>(R,G,B)</td>
#    </tr> <td>Decimal Code<br/>(R,G,B)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>1</td>
#       <td style="background:lightsalmon;"> </td>
#       <td>lightsalmon</td>
#       <td>#FFA07A</td>
#       <td>rgb(255,160,122)</td>
#    </tr> <td>1</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>1</td>
#       <td style="background:lightsalmon;"> </td>
#       <td>lightsalmon</td>
#       <td>#FFA07A</td>
#       <td>rgb(255,160,122)</td>
#    </tr> <td style="background:lightsalmon;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>1</td>
#       <td style="background:lightsalmon;"> </td>
#       <td>lightsalmon</td>
#       <td>#FFA07A</td>
#       <td>rgb(255,160,122)</td>
#    </tr> <td>lightsalmon</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>1</td>
#       <td style="background:lightsalmon;"> </td>
#       <td>lightsalmon</td>
#       <td>#FFA07A</td>
#       <td>rgb(255,160,122)</td>
#    </tr> <td>#FFA07A</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>1</td>
#       <td style="background:lightsalmon;"> </td>
#       <td>lightsalmon</td>
#       <td>#FFA07A</td>
#       <td>rgb(255,160,122)</td>
#    </tr> <td>rgb(255,160,122)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>2</td>
#       <td style="background:salmon;"> </td>
#       <td>salmon</td>
#       <td>#FA8072</td>
#       <td>rgb(250,128,114)</td>
#    </tr> <td>2</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>2</td>
#       <td style="background:salmon;"> </td>
#       <td>salmon</td>
#       <td>#FA8072</td>
#       <td>rgb(250,128,114)</td>
#    </tr> <td style="background:salmon;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>2</td>
#       <td style="background:salmon;"> </td>
#       <td>salmon</td>
#       <td>#FA8072</td>
#       <td>rgb(250,128,114)</td>
#    </tr> <td>salmon</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>2</td>
#       <td style="background:salmon;"> </td>
#       <td>salmon</td>
#       <td>#FA8072</td>
#       <td>rgb(250,128,114)</td>
#    </tr> <td>#FA8072</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>2</td>
#       <td style="background:salmon;"> </td>
#       <td>salmon</td>
#       <td>#FA8072</td>
#       <td>rgb(250,128,114)</td>
#    </tr> <td>rgb(250,128,114)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>3</td>
#       <td style="background:darksalmon;"> </td>
#       <td>darksalmon</td>
#       <td>#E9967A</td>
#       <td>rgb(233,150,122)</td>
#    </tr> <td>3</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>3</td>
#       <td style="background:darksalmon;"> </td>
#       <td>darksalmon</td>
#       <td>#E9967A</td>
#       <td>rgb(233,150,122)</td>
#    </tr> <td style="background:darksalmon;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>3</td>
#       <td style="background:darksalmon;"> </td>
#       <td>darksalmon</td>
#       <td>#E9967A</td>
#       <td>rgb(233,150,122)</td>
#    </tr> <td>darksalmon</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>3</td>
#       <td style="background:darksalmon;"> </td>
#       <td>darksalmon</td>
#       <td>#E9967A</td>
#       <td>rgb(233,150,122)</td>
#    </tr> <td>#E9967A</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>3</td>
#       <td style="background:darksalmon;"> </td>
#       <td>darksalmon</td>
#       <td>#E9967A</td>
#       <td>rgb(233,150,122)</td>
#    </tr> <td>rgb(233,150,122)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>4</td>
#       <td style="background:lightcoral;"> </td>
#       <td>lightcoral</td>
#       <td>#F08080</td>
#       <td>rgb(240,128,128)</td>
#    </tr> <td>4</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>4</td>
#       <td style="background:lightcoral;"> </td>
#       <td>lightcoral</td>
#       <td>#F08080</td>
#       <td>rgb(240,128,128)</td>
#    </tr> <td style="background:lightcoral;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>4</td>
#       <td style="background:lightcoral;"> </td>
#       <td>lightcoral</td>
#       <td>#F08080</td>
#       <td>rgb(240,128,128)</td>
#    </tr> <td>lightcoral</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>4</td>
#       <td style="background:lightcoral;"> </td>
#       <td>lightcoral</td>
#       <td>#F08080</td>
#       <td>rgb(240,128,128)</td>
#    </tr> <td>#F08080</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>4</td>
#       <td style="background:lightcoral;"> </td>
#       <td>lightcoral</td>
#       <td>#F08080</td>
#       <td>rgb(240,128,128)</td>
#    </tr> <td>rgb(240,128,128)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>5</td>
#       <td style="background:coral;"> </td>
#       <td>coral</td>
#       <td>#FF7F50</td>
#       <td>rgb(255,127,80)</td>
#    </tr> <td>5</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>5</td>
#       <td style="background:coral;"> </td>
#       <td>coral</td>
#       <td>#FF7F50</td>
#       <td>rgb(255,127,80)</td>
#    </tr> <td style="background:coral;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>5</td>
#       <td style="background:coral;"> </td>
#       <td>coral</td>
#       <td>#FF7F50</td>
#       <td>rgb(255,127,80)</td>
#    </tr> <td>coral</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>5</td>
#       <td style="background:coral;"> </td>
#       <td>coral</td>
#       <td>#FF7F50</td>
#       <td>rgb(255,127,80)</td>
#    </tr> <td>#FF7F50</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>5</td>
#       <td style="background:coral;"> </td>
#       <td>coral</td>
#       <td>#FF7F50</td>
#       <td>rgb(255,127,80)</td>
#    </tr> <td>rgb(255,127,80)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>6</td>
#       <td style="background:tomato;"> </td>
#       <td>tomato</td>
#       <td>#FF6347</td>
#       <td>rgb(255,99,71)</td>
#    </tr> <td>6</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>6</td>
#       <td style="background:tomato;"> </td>
#       <td>tomato</td>
#       <td>#FF6347</td>
#       <td>rgb(255,99,71)</td>
#    </tr> <td style="background:tomato;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>6</td>
#       <td style="background:tomato;"> </td>
#       <td>tomato</td>
#       <td>#FF6347</td>
#       <td>rgb(255,99,71)</td>
#    </tr> <td>tomato</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>6</td>
#       <td style="background:tomato;"> </td>
#       <td>tomato</td>
#       <td>#FF6347</td>
#       <td>rgb(255,99,71)</td>
#    </tr> <td>#FF6347</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>6</td>
#       <td style="background:tomato;"> </td>
#       <td>tomato</td>
#       <td>#FF6347</td>
#       <td>rgb(255,99,71)</td>
#    </tr> <td>rgb(255,99,71)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>7</td>
#       <td style="background:orangered;"> </td>
#       <td>orangered</td>
#       <td>#FF4500</td>
#       <td>rgb(255,69,0)</td>
#    </tr> <td>7</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>7</td>
#       <td style="background:orangered;"> </td>
#       <td>orangered</td>
#       <td>#FF4500</td>
#       <td>rgb(255,69,0)</td>
#    </tr> <td style="background:orangered;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>7</td>
#       <td style="background:orangered;"> </td>
#       <td>orangered</td>
#       <td>#FF4500</td>
#       <td>rgb(255,69,0)</td>
#    </tr> <td>orangered</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>7</td>
#       <td style="background:orangered;"> </td>
#       <td>orangered</td>
#       <td>#FF4500</td>
#       <td>rgb(255,69,0)</td>
#    </tr> <td>#FF4500</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>7</td>
#       <td style="background:orangered;"> </td>
#       <td>orangered</td>
#       <td>#FF4500</td>
#       <td>rgb(255,69,0)</td>
#    </tr> <td>rgb(255,69,0)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>8</td>
#       <td style="background:gold;"> </td>
#       <td>gold</td>
#       <td>#FFD700</td>
#       <td>rgb(255,215,0)</td>
#    </tr> <td>8</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>8</td>
#       <td style="background:gold;"> </td>
#       <td>gold</td>
#       <td>#FFD700</td>
#       <td>rgb(255,215,0)</td>
#    </tr> <td style="background:gold;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>8</td>
#       <td style="background:gold;"> </td>
#       <td>gold</td>
#       <td>#FFD700</td>
#       <td>rgb(255,215,0)</td>
#    </tr> <td>gold</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>8</td>
#       <td style="background:gold;"> </td>
#       <td>gold</td>
#       <td>#FFD700</td>
#       <td>rgb(255,215,0)</td>
#    </tr> <td>#FFD700</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>8</td>
#       <td style="background:gold;"> </td>
#       <td>gold</td>
#       <td>#FFD700</td>
#       <td>rgb(255,215,0)</td>
#    </tr> <td>rgb(255,215,0)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>9</td>
#       <td style="background:orange;"> </td>
#       <td>orange</td>
#       <td>#FFA500</td>
#       <td>rgb(255,165,0)</td>
#    </tr> <td>9</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>9</td>
#       <td style="background:orange;"> </td>
#       <td>orange</td>
#       <td>#FFA500</td>
#       <td>rgb(255,165,0)</td>
#    </tr> <td style="background:orange;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>9</td>
#       <td style="background:orange;"> </td>
#       <td>orange</td>
#       <td>#FFA500</td>
#       <td>rgb(255,165,0)</td>
#    </tr> <td>orange</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>9</td>
#       <td style="background:orange;"> </td>
#       <td>orange</td>
#       <td>#FFA500</td>
#       <td>rgb(255,165,0)</td>
#    </tr> <td>#FFA500</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>9</td>
#       <td style="background:orange;"> </td>
#       <td>orange</td>
#       <td>#FFA500</td>
#       <td>rgb(255,165,0)</td>
#    </tr> <td>rgb(255,165,0)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>10</td>
#       <td style="background:darkorange;"> </td>
#       <td>darkorange</td>
#       <td>#FF8C00</td>
#       <td>rgb(255,140,0)</td>
#    </tr> <td>10</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>10</td>
#       <td style="background:darkorange;"> </td>
#       <td>darkorange</td>
#       <td>#FF8C00</td>
#       <td>rgb(255,140,0)</td>
#    </tr> <td style="background:darkorange;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>10</td>
#       <td style="background:darkorange;"> </td>
#       <td>darkorange</td>
#       <td>#FF8C00</td>
#       <td>rgb(255,140,0)</td>
#    </tr> <td>darkorange</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>10</td>
#       <td style="background:darkorange;"> </td>
#       <td>darkorange</td>
#       <td>#FF8C00</td>
#       <td>rgb(255,140,0)</td>
#    </tr> <td>#FF8C00</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>10</td>
#       <td style="background:darkorange;"> </td>
#       <td>darkorange</td>
#       <td>#FF8C00</td>
#       <td>rgb(255,140,0)</td>
#    </tr> <td>rgb(255,140,0)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>11</td>
#       <td style="background:lightyellow;"> </td>
#       <td>lightyellow</td>
#       <td>#FFFFE0</td>
#       <td>rgb(255,255,224)</td>
#    </tr> <td>11</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>11</td>
#       <td style="background:lightyellow;"> </td>
#       <td>lightyellow</td>
#       <td>#FFFFE0</td>
#       <td>rgb(255,255,224)</td>
#    </tr> <td style="background:lightyellow;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>11</td>
#       <td style="background:lightyellow;"> </td>
#       <td>lightyellow</td>
#       <td>#FFFFE0</td>
#       <td>rgb(255,255,224)</td>
#    </tr> <td>lightyellow</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>11</td>
#       <td style="background:lightyellow;"> </td>
#       <td>lightyellow</td>
#       <td>#FFFFE0</td>
#       <td>rgb(255,255,224)</td>
#    </tr> <td>#FFFFE0</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>11</td>
#       <td style="background:lightyellow;"> </td>
#       <td>lightyellow</td>
#       <td>#FFFFE0</td>
#       <td>rgb(255,255,224)</td>
#    </tr> <td>rgb(255,255,224)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>12</td>
#       <td style="background:lemonchiffon;"> </td>
#       <td>lemonchiffon</td>
#       <td>#FFFACD</td>
#       <td>rgb(255,250,205)</td>
#    </tr> <td>12</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>12</td>
#       <td style="background:lemonchiffon;"> </td>
#       <td>lemonchiffon</td>
#       <td>#FFFACD</td>
#       <td>rgb(255,250,205)</td>
#    </tr> <td style="background:lemonchiffon;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>12</td>
#       <td style="background:lemonchiffon;"> </td>
#       <td>lemonchiffon</td>
#       <td>#FFFACD</td>
#       <td>rgb(255,250,205)</td>
#    </tr> <td>lemonchiffon</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>12</td>
#       <td style="background:lemonchiffon;"> </td>
#       <td>lemonchiffon</td>
#       <td>#FFFACD</td>
#       <td>rgb(255,250,205)</td>
#    </tr> <td>#FFFACD</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>12</td>
#       <td style="background:lemonchiffon;"> </td>
#       <td>lemonchiffon</td>
#       <td>#FFFACD</td>
#       <td>rgb(255,250,205)</td>
#    </tr> <td>rgb(255,250,205)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>13</td>
#       <td style="background:papayawhip;"> </td>
#       <td>papayawhip</td>
#       <td>#FFEFD5</td>
#       <td>rgb(255,239,213)</td>
#    </tr> <td>13</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>13</td>
#       <td style="background:papayawhip;"> </td>
#       <td>papayawhip</td>
#       <td>#FFEFD5</td>
#       <td>rgb(255,239,213)</td>
#    </tr> <td style="background:papayawhip;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>13</td>
#       <td style="background:papayawhip;"> </td>
#       <td>papayawhip</td>
#       <td>#FFEFD5</td>
#       <td>rgb(255,239,213)</td>
#    </tr> <td>papayawhip</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>13</td>
#       <td style="background:papayawhip;"> </td>
#       <td>papayawhip</td>
#       <td>#FFEFD5</td>
#       <td>rgb(255,239,213)</td>
#    </tr> <td>#FFEFD5</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>13</td>
#       <td style="background:papayawhip;"> </td>
#       <td>papayawhip</td>
#       <td>#FFEFD5</td>
#       <td>rgb(255,239,213)</td>
#    </tr> <td>rgb(255,239,213)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>14</td>
#       <td style="background:moccasin;"> </td>
#       <td>moccasin</td>
#       <td>#FFE4B5</td>
#       <td>rgb(255,228,181)</td>
#    </tr> <td>14</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>14</td>
#       <td style="background:moccasin;"> </td>
#       <td>moccasin</td>
#       <td>#FFE4B5</td>
#       <td>rgb(255,228,181)</td>
#    </tr> <td style="background:moccasin;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>14</td>
#       <td style="background:moccasin;"> </td>
#       <td>moccasin</td>
#       <td>#FFE4B5</td>
#       <td>rgb(255,228,181)</td>
#    </tr> <td>moccasin</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>14</td>
#       <td style="background:moccasin;"> </td>
#       <td>moccasin</td>
#       <td>#FFE4B5</td>
#       <td>rgb(255,228,181)</td>
#    </tr> <td>#FFE4B5</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>14</td>
#       <td style="background:moccasin;"> </td>
#       <td>moccasin</td>
#       <td>#FFE4B5</td>
#       <td>rgb(255,228,181)</td>
#    </tr> <td>rgb(255,228,181)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>15</td>
#       <td style="background:peachpuff;"> </td>
#       <td>peachpuff</td>
#       <td>#FFDAB9</td>
#       <td>rgb(255,218,185)</td>
#    </tr> <td>15</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>15</td>
#       <td style="background:peachpuff;"> </td>
#       <td>peachpuff</td>
#       <td>#FFDAB9</td>
#       <td>rgb(255,218,185)</td>
#    </tr> <td style="background:peachpuff;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>15</td>
#       <td style="background:peachpuff;"> </td>
#       <td>peachpuff</td>
#       <td>#FFDAB9</td>
#       <td>rgb(255,218,185)</td>
#    </tr> <td>peachpuff</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>15</td>
#       <td style="background:peachpuff;"> </td>
#       <td>peachpuff</td>
#       <td>#FFDAB9</td>
#       <td>rgb(255,218,185)</td>
#    </tr> <td>#FFDAB9</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>15</td>
#       <td style="background:peachpuff;"> </td>
#       <td>peachpuff</td>
#       <td>#FFDAB9</td>
#       <td>rgb(255,218,185)</td>
#    </tr> <td>rgb(255,218,185)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>16</td>
#       <td style="background:palegoldenrod;"> </td>
#       <td>palegoldenrod</td>
#       <td>#EEE8AA</td>
#       <td>rgb(238,232,170)</td>
#    </tr> <td>16</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>16</td>
#       <td style="background:palegoldenrod;"> </td>
#       <td>palegoldenrod</td>
#       <td>#EEE8AA</td>
#       <td>rgb(238,232,170)</td>
#    </tr> <td style="background:palegoldenrod;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>16</td>
#       <td style="background:palegoldenrod;"> </td>
#       <td>palegoldenrod</td>
#       <td>#EEE8AA</td>
#       <td>rgb(238,232,170)</td>
#    </tr> <td>palegoldenrod</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>16</td>
#       <td style="background:palegoldenrod;"> </td>
#       <td>palegoldenrod</td>
#       <td>#EEE8AA</td>
#       <td>rgb(238,232,170)</td>
#    </tr> <td>#EEE8AA</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>16</td>
#       <td style="background:palegoldenrod;"> </td>
#       <td>palegoldenrod</td>
#       <td>#EEE8AA</td>
#       <td>rgb(238,232,170)</td>
#    </tr> <td>rgb(238,232,170)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>17</td>
#       <td style="background:khaki;"> </td>
#       <td>khaki</td>
#       <td>#F0E68C</td>
#       <td>rgb(240,230,140)</td>
#    </tr> <td>17</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>17</td>
#       <td style="background:khaki;"> </td>
#       <td>khaki</td>
#       <td>#F0E68C</td>
#       <td>rgb(240,230,140)</td>
#    </tr> <td style="background:khaki;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>17</td>
#       <td style="background:khaki;"> </td>
#       <td>khaki</td>
#       <td>#F0E68C</td>
#       <td>rgb(240,230,140)</td>
#    </tr> <td>khaki</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>17</td>
#       <td style="background:khaki;"> </td>
#       <td>khaki</td>
#       <td>#F0E68C</td>
#       <td>rgb(240,230,140)</td>
#    </tr> <td>#F0E68C</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>17</td>
#       <td style="background:khaki;"> </td>
#       <td>khaki</td>
#       <td>#F0E68C</td>
#       <td>rgb(240,230,140)</td>
#    </tr> <td>rgb(240,230,140)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>18</td>
#       <td style="background:darkkhaki;"> </td>
#       <td>darkkhaki</td>
#       <td>#BDB76B</td>
#       <td>rgb(189,183,107)</td>
#    </tr> <td>18</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>18</td>
#       <td style="background:darkkhaki;"> </td>
#       <td>darkkhaki</td>
#       <td>#BDB76B</td>
#       <td>rgb(189,183,107)</td>
#    </tr> <td style="background:darkkhaki;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>18</td>
#       <td style="background:darkkhaki;"> </td>
#       <td>darkkhaki</td>
#       <td>#BDB76B</td>
#       <td>rgb(189,183,107)</td>
#    </tr> <td>darkkhaki</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>18</td>
#       <td style="background:darkkhaki;"> </td>
#       <td>darkkhaki</td>
#       <td>#BDB76B</td>
#       <td>rgb(189,183,107)</td>
#    </tr> <td>#BDB76B</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>18</td>
#       <td style="background:darkkhaki;"> </td>
#       <td>darkkhaki</td>
#       <td>#BDB76B</td>
#       <td>rgb(189,183,107)</td>
#    </tr> <td>rgb(189,183,107)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>19</td>
#       <td style="background:yellow;"> </td>
#       <td>yellow</td>
#       <td>#FFFF00</td>
#       <td>rgb(255,255,0)</td>
#    </tr> <td>19</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>19</td>
#       <td style="background:yellow;"> </td>
#       <td>yellow</td>
#       <td>#FFFF00</td>
#       <td>rgb(255,255,0)</td>
#    </tr> <td style="background:yellow;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>19</td>
#       <td style="background:yellow;"> </td>
#       <td>yellow</td>
#       <td>#FFFF00</td>
#       <td>rgb(255,255,0)</td>
#    </tr> <td>yellow</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>19</td>
#       <td style="background:yellow;"> </td>
#       <td>yellow</td>
#       <td>#FFFF00</td>
#       <td>rgb(255,255,0)</td>
#    </tr> <td>#FFFF00</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>19</td>
#       <td style="background:yellow;"> </td>
#       <td>yellow</td>
#       <td>#FFFF00</td>
#       <td>rgb(255,255,0)</td>
#    </tr> <td>rgb(255,255,0)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>20</td>
#       <td style="background:lawngreen;"> </td>
#       <td>lawngreen</td>
#       <td>#7CFC00</td>
#       <td>rgb(124,252,0)</td>
#    </tr> <td>20</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>20</td>
#       <td style="background:lawngreen;"> </td>
#       <td>lawngreen</td>
#       <td>#7CFC00</td>
#       <td>rgb(124,252,0)</td>
#    </tr> <td style="background:lawngreen;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>20</td>
#       <td style="background:lawngreen;"> </td>
#       <td>lawngreen</td>
#       <td>#7CFC00</td>
#       <td>rgb(124,252,0)</td>
#    </tr> <td>lawngreen</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>20</td>
#       <td style="background:lawngreen;"> </td>
#       <td>lawngreen</td>
#       <td>#7CFC00</td>
#       <td>rgb(124,252,0)</td>
#    </tr> <td>#7CFC00</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>20</td>
#       <td style="background:lawngreen;"> </td>
#       <td>lawngreen</td>
#       <td>#7CFC00</td>
#       <td>rgb(124,252,0)</td>
#    </tr> <td>rgb(124,252,0)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>21</td>
#       <td style="background:chartreuse;"> </td>
#       <td>chartreuse</td>
#       <td>#7FFF00</td>
#       <td>rgb(127,255,0)</td>
#    </tr> <td>21</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>21</td>
#       <td style="background:chartreuse;"> </td>
#       <td>chartreuse</td>
#       <td>#7FFF00</td>
#       <td>rgb(127,255,0)</td>
#    </tr> <td style="background:chartreuse;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>21</td>
#       <td style="background:chartreuse;"> </td>
#       <td>chartreuse</td>
#       <td>#7FFF00</td>
#       <td>rgb(127,255,0)</td>
#    </tr> <td>chartreuse</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>21</td>
#       <td style="background:chartreuse;"> </td>
#       <td>chartreuse</td>
#       <td>#7FFF00</td>
#       <td>rgb(127,255,0)</td>
#    </tr> <td>#7FFF00</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>21</td>
#       <td style="background:chartreuse;"> </td>
#       <td>chartreuse</td>
#       <td>#7FFF00</td>
#       <td>rgb(127,255,0)</td>
#    </tr> <td>rgb(127,255,0)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>22</td>
#       <td style="background:limegreen;"> </td>
#       <td>limegreen</td>
#       <td>#32CD32</td>
#       <td>rgb(50,205,50)</td>
#    </tr> <td>22</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>22</td>
#       <td style="background:limegreen;"> </td>
#       <td>limegreen</td>
#       <td>#32CD32</td>
#       <td>rgb(50,205,50)</td>
#    </tr> <td style="background:limegreen;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>22</td>
#       <td style="background:limegreen;"> </td>
#       <td>limegreen</td>
#       <td>#32CD32</td>
#       <td>rgb(50,205,50)</td>
#    </tr> <td>limegreen</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>22</td>
#       <td style="background:limegreen;"> </td>
#       <td>limegreen</td>
#       <td>#32CD32</td>
#       <td>rgb(50,205,50)</td>
#    </tr> <td>#32CD32</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>22</td>
#       <td style="background:limegreen;"> </td>
#       <td>limegreen</td>
#       <td>#32CD32</td>
#       <td>rgb(50,205,50)</td>
#    </tr> <td>rgb(50,205,50)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>23</td>
#       <td style="background:lime;"> </td>
#       <td>lime</td>
#       <td>#00FF00</td>
#       <td>rgb(0.255.0)</td>
#    </tr> <td>23</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>23</td>
#       <td style="background:lime;"> </td>
#       <td>lime</td>
#       <td>#00FF00</td>
#       <td>rgb(0.255.0)</td>
#    </tr> <td style="background:lime;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>23</td>
#       <td style="background:lime;"> </td>
#       <td>lime</td>
#       <td>#00FF00</td>
#       <td>rgb(0.255.0)</td>
#    </tr> <td>lime</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>23</td>
#       <td style="background:lime;"> </td>
#       <td>lime</td>
#       <td>#00FF00</td>
#       <td>rgb(0.255.0)</td>
#    </tr> <td>#00FF00</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>23</td>
#       <td style="background:lime;"> </td>
#       <td>lime</td>
#       <td>#00FF00</td>
#       <td>rgb(0.255.0)</td>
#    </tr> <td>rgb(0.255.0)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>24</td>
#       <td style="background:forestgreen;"> </td>
#       <td>forestgreen</td>
#       <td>#228B22</td>
#       <td>rgb(34,139,34)</td>
#    </tr> <td>24</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>24</td>
#       <td style="background:forestgreen;"> </td>
#       <td>forestgreen</td>
#       <td>#228B22</td>
#       <td>rgb(34,139,34)</td>
#    </tr> <td style="background:forestgreen;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>24</td>
#       <td style="background:forestgreen;"> </td>
#       <td>forestgreen</td>
#       <td>#228B22</td>
#       <td>rgb(34,139,34)</td>
#    </tr> <td>forestgreen</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>24</td>
#       <td style="background:forestgreen;"> </td>
#       <td>forestgreen</td>
#       <td>#228B22</td>
#       <td>rgb(34,139,34)</td>
#    </tr> <td>#228B22</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>24</td>
#       <td style="background:forestgreen;"> </td>
#       <td>forestgreen</td>
#       <td>#228B22</td>
#       <td>rgb(34,139,34)</td>
#    </tr> <td>rgb(34,139,34)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>25</td>
#       <td style="background:green;"> </td>
#       <td>green</td>
#       <td>#008000</td>
#       <td>rgb(0,128,0)</td>
#    </tr> <td>25</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>25</td>
#       <td style="background:green;"> </td>
#       <td>green</td>
#       <td>#008000</td>
#       <td>rgb(0,128,0)</td>
#    </tr> <td style="background:green;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>25</td>
#       <td style="background:green;"> </td>
#       <td>green</td>
#       <td>#008000</td>
#       <td>rgb(0,128,0)</td>
#    </tr> <td>green</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>25</td>
#       <td style="background:green;"> </td>
#       <td>green</td>
#       <td>#008000</td>
#       <td>rgb(0,128,0)</td>
#    </tr> <td>#008000</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>25</td>
#       <td style="background:green;"> </td>
#       <td>green</td>
#       <td>#008000</td>
#       <td>rgb(0,128,0)</td>
#    </tr> <td>rgb(0,128,0)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>26</td>
#       <td style="background:powderblue;"> </td>
#       <td>powderblue</td>
#       <td>#B0E0E6</td>
#       <td>rgb(176,224,230)</td>
#    </tr> <td>26</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>26</td>
#       <td style="background:powderblue;"> </td>
#       <td>powderblue</td>
#       <td>#B0E0E6</td>
#       <td>rgb(176,224,230)</td>
#    </tr> <td style="background:powderblue;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>26</td>
#       <td style="background:powderblue;"> </td>
#       <td>powderblue</td>
#       <td>#B0E0E6</td>
#       <td>rgb(176,224,230)</td>
#    </tr> <td>powderblue</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>26</td>
#       <td style="background:powderblue;"> </td>
#       <td>powderblue</td>
#       <td>#B0E0E6</td>
#       <td>rgb(176,224,230)</td>
#    </tr> <td>#B0E0E6</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>26</td>
#       <td style="background:powderblue;"> </td>
#       <td>powderblue</td>
#       <td>#B0E0E6</td>
#       <td>rgb(176,224,230)</td>
#    </tr> <td>rgb(176,224,230)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>27</td>
#       <td style="background:lightblue;"> </td>
#       <td>lightblue</td>
#       <td>#ADD8E6</td>
#       <td>rgb(173,216,230)</td>
#    </tr> <td>27</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>27</td>
#       <td style="background:lightblue;"> </td>
#       <td>lightblue</td>
#       <td>#ADD8E6</td>
#       <td>rgb(173,216,230)</td>
#    </tr> <td style="background:lightblue;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>27</td>
#       <td style="background:lightblue;"> </td>
#       <td>lightblue</td>
#       <td>#ADD8E6</td>
#       <td>rgb(173,216,230)</td>
#    </tr> <td>lightblue</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>27</td>
#       <td style="background:lightblue;"> </td>
#       <td>lightblue</td>
#       <td>#ADD8E6</td>
#       <td>rgb(173,216,230)</td>
#    </tr> <td>#ADD8E6</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>27</td>
#       <td style="background:lightblue;"> </td>
#       <td>lightblue</td>
#       <td>#ADD8E6</td>
#       <td>rgb(173,216,230)</td>
#    </tr> <td>rgb(173,216,230)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>28</td>
#       <td style="background:lightskyblue;"> </td>
#       <td>lightskyblue</td>
#       <td>#87CEFA</td>
#       <td>rgb(135,206,250)</td>
#    </tr> <td>28</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>28</td>
#       <td style="background:lightskyblue;"> </td>
#       <td>lightskyblue</td>
#       <td>#87CEFA</td>
#       <td>rgb(135,206,250)</td>
#    </tr> <td style="background:lightskyblue;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>28</td>
#       <td style="background:lightskyblue;"> </td>
#       <td>lightskyblue</td>
#       <td>#87CEFA</td>
#       <td>rgb(135,206,250)</td>
#    </tr> <td>lightskyblue</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>28</td>
#       <td style="background:lightskyblue;"> </td>
#       <td>lightskyblue</td>
#       <td>#87CEFA</td>
#       <td>rgb(135,206,250)</td>
#    </tr> <td>#87CEFA</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>28</td>
#       <td style="background:lightskyblue;"> </td>
#       <td>lightskyblue</td>
#       <td>#87CEFA</td>
#       <td>rgb(135,206,250)</td>
#    </tr> <td>rgb(135,206,250)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>29</td>
#       <td style="background:skyblue;"> </td>
#       <td>skyblue</td>
#       <td>#87CEEB</td>
#       <td>rgb(135,206,235)</td>
#    </tr> <td>29</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>29</td>
#       <td style="background:skyblue;"> </td>
#       <td>skyblue</td>
#       <td>#87CEEB</td>
#       <td>rgb(135,206,235)</td>
#    </tr> <td style="background:skyblue;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>29</td>
#       <td style="background:skyblue;"> </td>
#       <td>skyblue</td>
#       <td>#87CEEB</td>
#       <td>rgb(135,206,235)</td>
#    </tr> <td>skyblue</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>29</td>
#       <td style="background:skyblue;"> </td>
#       <td>skyblue</td>
#       <td>#87CEEB</td>
#       <td>rgb(135,206,235)</td>
#    </tr> <td>#87CEEB</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>29</td>
#       <td style="background:skyblue;"> </td>
#       <td>skyblue</td>
#       <td>#87CEEB</td>
#       <td>rgb(135,206,235)</td>
#    </tr> <td>rgb(135,206,235)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>30</td>
#       <td style="background:deepskyblue;"> </td>
#       <td>deepskyblue</td>
#       <td>#00BFFF</td>
#       <td>rgb(0,191,255)</td>
#    </tr> <td>30</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>30</td>
#       <td style="background:deepskyblue;"> </td>
#       <td>deepskyblue</td>
#       <td>#00BFFF</td>
#       <td>rgb(0,191,255)</td>
#    </tr> <td style="background:deepskyblue;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>30</td>
#       <td style="background:deepskyblue;"> </td>
#       <td>deepskyblue</td>
#       <td>#00BFFF</td>
#       <td>rgb(0,191,255)</td>
#    </tr> <td>deepskyblue</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>30</td>
#       <td style="background:deepskyblue;"> </td>
#       <td>deepskyblue</td>
#       <td>#00BFFF</td>
#       <td>rgb(0,191,255)</td>
#    </tr> <td>#00BFFF</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>30</td>
#       <td style="background:deepskyblue;"> </td>
#       <td>deepskyblue</td>
#       <td>#00BFFF</td>
#       <td>rgb(0,191,255)</td>
#    </tr> <td>rgb(0,191,255)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>31</td>
#       <td style="background:lightsteelblue;"> </td>
#       <td>lightsteelblue</td>
#       <td>#B0C4DE</td>
#       <td>rgb(176,196,222)</td>
#    </tr> <td>31</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>31</td>
#       <td style="background:lightsteelblue;"> </td>
#       <td>lightsteelblue</td>
#       <td>#B0C4DE</td>
#       <td>rgb(176,196,222)</td>
#    </tr> <td style="background:lightsteelblue;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>31</td>
#       <td style="background:lightsteelblue;"> </td>
#       <td>lightsteelblue</td>
#       <td>#B0C4DE</td>
#       <td>rgb(176,196,222)</td>
#    </tr> <td>lightsteelblue</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>31</td>
#       <td style="background:lightsteelblue;"> </td>
#       <td>lightsteelblue</td>
#       <td>#B0C4DE</td>
#       <td>rgb(176,196,222)</td>
#    </tr> <td>#B0C4DE</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>31</td>
#       <td style="background:lightsteelblue;"> </td>
#       <td>lightsteelblue</td>
#       <td>#B0C4DE</td>
#       <td>rgb(176,196,222)</td>
#    </tr> <td>rgb(176,196,222)</td>
# <class 'bs4.element.Tag'>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>32</td>
#       <td style="background:dodgerblue;"> </td>
#       <td>dodgerblue</td>
#       <td>#1E90FF</td>
#       <td>rgb(30,144,255)</td>
#    </tr> <td>32</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>32</td>
#       <td style="background:dodgerblue;"> </td>
#       <td>dodgerblue</td>
#       <td>#1E90FF</td>
#       <td>rgb(30,144,255)</td>
#    </tr> <td style="background:dodgerblue;"> </td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>32</td>
#       <td style="background:dodgerblue;"> </td>
#       <td>dodgerblue</td>
#       <td>#1E90FF</td>
#       <td>rgb(30,144,255)</td>
#    </tr> <td>dodgerblue</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>32</td>
#       <td style="background:dodgerblue;"> </td>
#       <td>dodgerblue</td>
#       <td>#1E90FF</td>
#       <td>rgb(30,144,255)</td>
#    </tr> <td>#1E90FF</td>
# <class 'bs4.element.Tag'> <class 'bs4.element.Tag'>
# <tr>
#       <td>32</td>
#       <td style="background:dodgerblue;"> </td>
#       <td>dodgerblue</td>
#       <td>#1E90FF</td>
#       <td>rgb(30,144,255)</td>
#    </tr> <td>rgb(30,144,255)</td>

# %% [markdown]
# ### Scrape data from HTML tables into a DataFrame using BeautifulSoup and Pandas

# %%
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/World_population"

# %%
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html5lib")

# %%
tables = soup.find_all('table')

# %%
len(tables)
# Out:
# 26

# %%
for index,table in enumerate(tables):
    if ("10 most densely populated countries" in str(table)):
        table_index = index
print(table_index)
# Out:
# 5

# %%
print(tables[table_index].prettify())
# Out:
# <table class="wikitable sortable" style="text-align:right">
#  <caption>
#   10 most densely populated countries
#   <small>
#    (with population above 5 million)
#   </small>
#  </caption>
#  <tbody>
#   <tr>
#    <th>
#     Rank
#    </th>
#    <th>
#     Country
#    </th>
#    <th>
#     Population
#    </th>
#    <th>
#     Area
#     <br/>
#     <small>
#      (km
#      <sup>
#       2
#      </sup>
#      )
#     </small>
#    </th>
#    <th>
#     Density
#     <br/>
#     <small>
#      (pop/km
#      <sup>
#       2
#      </sup>
#      )
#     </small>
#    </th>
#   </tr>
#   <tr>
#    <td>
#     1
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/23px-Flag_of_Singapore.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/35px-Flag_of_Singapore.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/48/Flag_of_Singapore.svg/45px-Flag_of_Singapore.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Singapore" title="Singapore">
#      Singapore
#     </a>
#    </td>
#    <td>
#     5,704,000
#    </td>
#    <td>
#     710
#    </td>
#    <td>
#     8,033
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/23px-Flag_of_Bangladesh.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/35px-Flag_of_Bangladesh.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f9/Flag_of_Bangladesh.svg/46px-Flag_of_Bangladesh.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Bangladesh" title="Bangladesh">
#      Bangladesh
#     </a>
#    </td>
#    <td>
#     171,530,000
#    </td>
#    <td>
#     143,998
#    </td>
#    <td>
#     1,191
#    </td>
#   </tr>
#   <tr>
#    <td>
#     3
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/23px-Flag_of_Lebanon.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/35px-Flag_of_Lebanon.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/45px-Flag_of_Lebanon.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Lebanon" title="Lebanon">
#      Lebanon
#     </a>
#    </td>
#    <td>
#     6,856,000
#    </td>
#    <td>
#     10,452
#    </td>
#    <td>
#     656
#    </td>
#   </tr>
#   <tr>
#    <td>
#     4
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/23px-Flag_of_the_Republic_of_China.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/35px-Flag_of_the_Republic_of_China.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/72/Flag_of_the_Republic_of_China.svg/45px-Flag_of_the_Republic_of_China.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Taiwan" title="Taiwan">
#      Taiwan
#     </a>
#    </td>
#    <td>
#     23,604,000
#    </td>
#    <td>
#     36,193
#    </td>
#    <td>
#     652
#    </td>
#   </tr>
#   <tr>
#    <td>
#     5
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/23px-Flag_of_South_Korea.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/35px-Flag_of_South_Korea.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/09/Flag_of_South_Korea.svg/45px-Flag_of_South_Korea.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/South_Korea" title="South Korea">
#      South Korea
#     </a>
#    </td>
#    <td>
#     51,781,000
#    </td>
#    <td>
#     99,538
#    </td>
#    <td>
#     520
#    </td>
#   </tr>
#   <tr>
#    <td>
#     6
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="720" data-file-width="1080" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/23px-Flag_of_Rwanda.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/35px-Flag_of_Rwanda.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/17/Flag_of_Rwanda.svg/45px-Flag_of_Rwanda.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Rwanda" title="Rwanda">
#      Rwanda
#     </a>
#    </td>
#    <td>
#     12,374,000
#    </td>
#    <td>
#     26,338
#    </td>
#    <td>
#     470
#    </td>
#   </tr>
#   <tr>
#    <td>
#     7
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/23px-Flag_of_Haiti.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/35px-Flag_of_Haiti.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/46px-Flag_of_Haiti.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Haiti" title="Haiti">
#      Haiti
#     </a>
#    </td>
#    <td>
#     11,578,000
#    </td>
#    <td>
#     27,065
#    </td>
#    <td>
#     428
#    </td>
#   </tr>
#   <tr>
#    <td>
#     8
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/23px-Flag_of_the_Netherlands.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/35px-Flag_of_the_Netherlands.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/20/Flag_of_the_Netherlands.svg/45px-Flag_of_the_Netherlands.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/Netherlands" title="Netherlands">
#      Netherlands
#     </a>
#    </td>
#    <td>
#     17,650,000
#    </td>
#    <td>
#     41,526
#    </td>
#    <td>
#     425
#    </td>
#   </tr>
#   <tr>
#    <td>
#     9
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="800" data-file-width="1100" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/21px-Flag_of_Israel.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/32px-Flag_of_Israel.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Israel.svg/41px-Flag_of_Israel.svg.png 2x" width="21"/>
#     </span>
#     <a href="/wiki/Israel" title="Israel">
#      Israel
#     </a>
#    </td>
#    <td>
#     9,420,000
#    </td>
#    <td>
#     22,072
#    </td>
#    <td>
#     427
#    </td>
#   </tr>
#   <tr>
#    <td>
#     10
#    </td>
#    <td align="left">
#     <span class="flagicon">
#      <img alt="" class="thumbborder" data-file-height="900" data-file-width="1350" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/23px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/35px-Flag_of_India.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/45px-Flag_of_India.svg.png 2x" width="23"/>
#     </span>
#     <a href="/wiki/India" title="India">
#      India
#     </a>
#    </td>
#    <td>
#     1,383,160,000
#    </td>
#    <td>
#     3,287,240
#    </td>
#    <td>
#     421
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
population_data = pd.DataFrame(columns=["Rank", "Country", "Population", "Area", "Density"])

for row in tables[table_index].tbody.find_all("tr"):
    col = row.find_all("td")
    if (col != []):
        rank = col[0].text
        country = col[1].text
        population = col[2].text.strip()
        area = col[3].text.strip()
        density = col[4].text.strip()
        population_data = population_data.append({"Rank":rank, "Country":country, "Population":population, "Area":area, "Density":density}, ignore_index=True)

population_data
# Out:
#   Rank       Country     Population       Area Density
# 0    1     Singapore      5,704,000        710   8,033
# 1    2    Bangladesh    171,530,000    143,998   1,191
# 2    3       Lebanon      6,856,000     10,452     656
# 3    4        Taiwan     23,604,000     36,193     652
# 4    5   South Korea     51,781,000     99,538     520
# 5    6        Rwanda     12,374,000     26,338     470
# 6    7         Haiti     11,578,000     27,065     428
# 7    8   Netherlands     17,650,000     41,526     425
# 8    9        Israel      9,420,000     22,072     427
# 9   10         India  1,383,160,000  3,287,240     421

# %%
dict = {"1":"1",1:2,11.0:"11.0","1":"2"}

# %%
print(dict)
# Out:
# {'1': '2', 1: 2, 11.0: '11.0'}

# %%
'1,2,3,4'.join(',')
# Out:
# ','
